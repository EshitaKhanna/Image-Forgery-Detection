# %%
import os
import numpy as np
from glob import glob
from skimage import io
from skimage.util import view_as_windows
import matplotlib.pyplot as plt
import cv2
from skimage.metrics import structural_similarity
from PIL import Image
import tensorflow as tf

# %%
def initialize_patch_extractor(input_path, output_path, patches_per_image=4, rotations=8, stride=8, mode='no_rot'):
    """
    Initializes parameters for patch extraction.
    """
    rotations_list = [0, 90, 180, 270][:rotations]  # Select rotations based on user input
    relevant_indices = [3, 6, 7, 12]
    
    authentic_images_list = glob(os.path.join(input_path, 'Au', '*'))
    authentic_images_dict = {
        path.split(os.sep)[-1][relevant_indices[0]:relevant_indices[1]] + path.split(os.sep)[-1][relevant_indices[2]:relevant_indices[3]]:
        path for path in authentic_images_list
    }

    return {
        'patches_per_image': patches_per_image,
        'stride': stride,
        'rotations': rotations_list,
        'mode': mode,
        'input_path': input_path,
        'output_path': output_path,
        'au_img_dict': authentic_images_dict,
        'background_index': [13, 21]
    }

# %%
def extract_patches_from_image(image, window_shape, stride, num_of_patches, rotations, output_path, im_name, rep_num, mode, patch_type):
    """
    Extracts and saves patches from an image, optionally applying rotations.
    """
    # Extract patches from the image
    windows = view_as_windows(image, window_shape, step=stride)
    patches = [window[0] for window in windows.reshape(-1, *window_shape)]

    # Select random patches
    selected_indices = np.random.choice(len(patches), num_of_patches, replace=False)

    for i, index in enumerate(selected_indices):
        patch = patches[index]
        if mode == 'rot':
            # Save rotated patches
            pil_patch = Image.fromarray(np.uint8(patch))
            for angle in rotations:
                rotated_patch = pil_patch.rotate(angle, resample=Image.BILINEAR)
                rotated_patch.save(f"{output_path}/{patch_type}/{im_name}_{i}_{angle}_{rep_num}.png")
        else:
            # Save patches without rotation
            io.imsave(f"{output_path}/{patch_type}/{im_name}_{i}_{rep_num}.png", patch)

# %%
def process_tampered_image(image_path, config, rep_num):
    """
    Processes a tampered image to extract and save patches.
    """
    image = io.imread(image_path)
    im_name = os.path.splitext(os.path.basename(image_path))[0]
    mask_path = os.path.join(config['input_path'], 'masks', f"{im_name}_gt.png")
    mask = io.imread(mask_path)
    image, mask = check_and_reshape(image, mask)

    tampered_patches, num_of_patches = find_tampered_patches(
        image, im_name, mask, (128, 128, 3), config['stride'], 'casia2', config['patches_per_image']
    )
    
    extract_patches_from_image(
        image, (128, 128, 3), config['stride'], num_of_patches, config['rotations'],
        config['output_path'], im_name, rep_num, config['mode'], 'tampered'
    )
    extract_authentic_patches(config, image_path, num_of_patches, rep_num)

# %%
def extract_authentic_patches(config, tampered_image_path, num_of_patches, rep_num):
    """
    Extracts and saves patches from an authentic image.
    """
    tampered_image_key = tampered_image_path.split(os.sep)[-1][config['background_index'][0]:config['background_index'][1]]
    
    if tampered_image_key in config['au_img_dict']:
        authentic_image_name = os.path.splitext(os.path.basename(config['au_img_dict'][tampered_image_key]))[0]
        au_image = plt.imread(config['au_img_dict'][tampered_image_key])
        
        extract_patches_from_image(
            au_image, (128, 128, 3), config['stride'], num_of_patches, config['rotations'],
            config['output_path'], authentic_image_name, rep_num, config['mode'], 'authentic'
        )

# %%
def extract_patches(config):
    """
    Extracts patches from tampered and authentic images.
    """
    os.makedirs(config['output_path'], exist_ok=True)
    for subdir in ['authentic', 'tampered']:
        os.makedirs(os.path.join(config['output_path'], subdir), exist_ok=True)

    tp_dir = os.path.join(config['input_path'], 'Tp')
    rep_num = 0

    for f in os.listdir(tp_dir):
        try:
            rep_num += 1
            process_tampered_image(os.path.join(tp_dir, f), config, rep_num)
        except (IOError, IndexError) as e:
            rep_num -= 1
            print(str(e))

# %%
def find_tampered_patches(image, im_name, mask, window_shape, stride, dataset, patches_per_image):
    """
    Finds tampered patches from an image and mask.
    """
    image_patches = view_as_windows(image, window_shape, step=stride)
    mask_patches = view_as_windows(mask, window_shape, step=stride)

    tampered_patches = []
    
    for i in range(image_patches.shape[0]):
        for j in range(image_patches.shape[1]):
            img_patch = image_patches[i, j, 0]
            mask_patch = mask_patches[i, j, 0]
            num_zeros = np.sum(mask_patch == 0)
            num_ones = np.sum(mask_patch == 255)
            total = num_ones + num_zeros
            
            if dataset == 'casia2' and num_zeros <= 0.99 * total:
                tampered_patches.append(img_patch)
            elif dataset == 'nc16' and 0.80 * total >= num_ones >= 0.20 * total:
                tampered_patches.append(img_patch)

    num_of_patches = min(len(tampered_patches), patches_per_image)
    if len(tampered_patches) < patches_per_image:
        print(f"Number of tampered patches for image {im_name} is only {len(tampered_patches)}")

    return tampered_patches, num_of_patches

# %%
def check_and_reshape(image, input_mask):
    """
    Ensures the mask matches the image size and format.
    """
    if input_mask.ndim == 2:
        mask = np.stack([input_mask] * 3, axis=-1)
    else:
        mask = input_mask

    if image.shape != mask.shape:
        if image.shape[0] == mask.shape[1] and image.shape[1] == mask.shape[0]:
            mask = np.reshape(mask, (image.shape[0], image.shape[1], mask.shape[2]))

    return image, mask

# %%
def find_mask(tampered_image_path, authentic_images_dict):
    """
    Creates and saves a mask of the image indicating the tampered region.
    """
    relevant_indices = [13, 21]
    save_name = os.path.splitext(os.path.basename(tampered_image_path))[0]
    tampered_image_key = os.path.basename(tampered_image_path)[relevant_indices[0]:relevant_indices[1]]

    if tampered_image_key in authentic_images_dict:
        authentic_image_path = authentic_images_dict[tampered_image_key]
        authentic_image = plt.imread(authentic_image_path)
        tampered_image = plt.imread(tampered_image_path)
        
        if tampered_image.shape == authentic_image.shape:
            gray_authentic_image = cv2.cvtColor(authentic_image, cv2.COLOR_BGR2GRAY)
            gray_tampered_image = cv2.cvtColor(tampered_image, cv2.COLOR_BGR2GRAY)
            
            (_, diff) = structural_similarity(gray_authentic_image, gray_tampered_image, full=True)
            diff = cv2.medianBlur(diff.astype(np.float32), 1)
            
            mask = np.where(diff < 0.98, 255, 0).astype("uint8")
            
            cv2.imwrite(f'masks/{save_name}_gt.png', mask)

# %%
def extract_masks():
    """
    Extract and save masks for all tampered images in the dataset.
    """
    save_dir = 'masks'
    os.makedirs(save_dir, exist_ok=True)

    authentic_image_paths = glob(os.path.join('CASIA2', 'Au', '*'))
    tampered_image_paths = glob(os.path.join('CASIA2', 'Tp', '*'))

    relevant_indices = [3, 6, 7, 12]
    authentic_images_dict = {
        path.split(os.sep)[-1][relevant_indices[0]:relevant_indices[1]] + path.split(os.sep)[-1][relevant_indices[2]:relevant_indices[3]]:
        path for path in authentic_image_paths
    }
    
    for tampered_image_path in tampered_image_paths:
        find_mask(tampered_image_path, authentic_images_dict)

# %%
# Configuration dictionary
config = {
    'input_path': 'CASIA2',
    'output_path': 'patches_with_rot',
    'patches_per_image': 2,
    'rotations': [0, 90, 180, 270],
    'stride': 128,
    'mode': 'rot',  # 'rot' for rotation, 'no_rot' for no rotation
    'background_index': [13, 21],  # Ensure this key is present
    'au_img_dict': {}  # This should be populated based on your image paths
}

# %%
config = initialize_patch_extractor( 
    input_path = 'CASIA2',
    output_path = 'patches_with_rot',
    patches_per_image = 2,
    rotations = 4,
    stride = 128,
    mode = 'rot',  # 'rot' for rotation, 'no_rot' for no rotation
)

# %%
extract_masks()

# %%
extract_patches(config)
# Out:
# Number of tampered patches for image Tp_S_NRD_S_N_pla20019_pla20019_02390 is only 0
# Number of tampered patches for image Tp_S_NNN_S_B_art00070_art00070_01241 is only 1
# Number of tampered patches for image Tp_D_NRD_S_N_sec00001_cha00042_00001 is only 1
# Number of tampered patches for image Tp_D_CRN_S_N_sec00071_art00028_11281 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_arc00098_ani00098_00318 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_ind00022_ind00088_00438 is only 1
# Number of tampered patches for image Tp_D_NRN_S_B_nat00023_cha00024_20076 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ind20010_ind20010_01751 is only 0
# Number of tampered patches for image Tp_S_NNN_S_N_arc20062_arc20062_01702 is only 0
# Number of tampered patches for image Tp_S_NNN_S_N_cha00002_cha00002_00837 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ani10115_ani10115_11656 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00091_nat00091_00993 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani00086_ani00086_11125 is only 1
# Number of tampered patches for image Tp_S_NRD_S_B_ani00027_ani00027_00147 is only 1
# Number of tampered patches for image Tp_D_CRN_M_N_ani10101_ani00081_10139 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_art00020_art00020_20029 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_pla10127_pla10127_12137 is only 1
# Number of tampered patches for image Tp_D_CRN_S_N_nat10145_ani00099_11990 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20031_arc20031_01484 is only 0
# Number of tampered patches for image Tp_D_CRD_S_N_sec00005_sec00003_00025 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00011_nat00011_00937 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani00087_ani00087_00814 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_arc00050_arc00050_01076 is only 1
# Number of tampered patches for image Tp_D_NNN_S_N_ani20069_ani20070_02111 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20053_ind20053_02299 is only 1
# Number of tampered patches for image Tp_S_NRD_M_B_sec00064_sec00064_00085 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20012_ind20012_02271 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NRD_S_N_ani20066_ani20066_02108_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_arc00096_arc00096_01034 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_art00025_ani10123_11689 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_arc00037_arc00037_10144 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NRN_S_B_txt00022_txt00022_20090_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_B_nat00073_nat00073_00979 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ind00019_ind00019_01317 is only 1
# Number of tampered patches for image Tp_S_NRN_S_B_sec20017_sec20017_01607 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_nat00065_nat00065_00975 is only 1
# Number of tampered patches for image Tp_D_NNN_S_N_ind00088_ind00066_00483 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani10171_ani10171_12456 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00034_arc00034_01090 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20003_ind20003_01744 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00072_nat00072_00673 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc10101_arc10101_11168 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_ani20032_ani20032_02075 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_sec00085_art00020_11456 is only 1
# Could not find a backend to open `CASIA2/Tp/Thumbs.db`` with iomode `r`.
# Number of tampered patches for image Tp_D_CRN_S_B_cha00085_ani00064_00405 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20061_nat20061_01565 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_nat20001_nat20001_02201 is only 0
# Number of tampered patches for image Tp_D_NRN_S_N_nat20084_nat20082_01588 is only 1
# Number of tampered patches for image Tp_D_NRN_M_N_ani00048_ani00037_10038 is only 1
# Number of tampered patches for image Tp_S_NRD_S_N_arc00043_arc00043_00263 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art10111_art10111_11562 is only 1
# Number of tampered patches for image Tp_D_CNN_S_N_pla10114_ani00081_10429 is only 0
# Number of tampered patches for image Tp_D_NRN_S_B_ani00021_ani00020_20015 is only 1
# Number of tampered patches for image Tp_S_CRN_S_B_txt00031_txt00031_01272 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00042_nat00042_00656 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc10101_arc10101_11169 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_arc00098_arc00098_01032 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla00051_pla00051_01160 is only 1
# Number of tampered patches for image Tp_D_NNN_S_N_nat00042_nat00042_00961 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NRN_S_B_ind00025_cha10101_10050_gt.png'
# Number of tampered patches for image Tp_D_NRN_S_N_nat10125_ani00017_11636 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_art20035_art20036_02492 is only 1
# Number of tampered patches for image Tp_S_CND_S_N_ind00069_ind00069_01356 is only 1
# Number of tampered patches for image Tp_D_CRN_M_N_ani10104_ani00097_10092 is only 0
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_CRN_S_N_cha10113_cha10113_11543_gt.png'
# Number of tampered patches for image Tp_D_NNN_S_B_cha00100_cha00020_00420 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_sec00064_sec00064_00741 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_cha00062_cha00062_00381 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_cha00049_cha00049_00852 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani20047_ani20047_02455 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00083_sec00083_00103 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_sec20005_sec20005_01440 is only 0
# Number of tampered patches for image Tp_D_NNN_S_N_sec00098_sec00082_10364 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec20061_sec20061_01651 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_cha10181_cha10181_12296 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ind20047_ind20047_02295 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art20080_art20080_02315 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_txt00026_txt00026_01271 is only 1
# Number of tampered patches for image Tp_S_NND_S_B_art00075_art00075_01245 is only 1
# Number of tampered patches for image Tp_D_CRN_S_O_cha00099_ani00061_10045 is only 1
# Number of tampered patches for image Tp_D_NRN_M_O_sec10101_sec10107_10024 is only 1
# Number of tampered patches for image Tp_D_CRN_M_O_arc00025_ani00039_10004 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NND_S_N_sec20064_sec20064_01654_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_B_arc00056_arc00056_00276 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_nat20097_nat20097_02257 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_cha00081_cha00081_10190 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla00054_pla00054_00588 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_art00021_art00092_11725 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00067_nat00067_10611 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00035_nat00035_00955 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NRN_S_N_pla20080_pla20080_01980_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_ind20064_ind20064_02305 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_art20009_art20009_01815 is only 0
# Number of tampered patches for image Tp_D_NRN_S_N_nat00098_cha00072_11462 is only 1
# Number of tampered patches for image Tp_D_NNN_S_N_arc00017_ani00058_00237 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_ani00076_ani00077_00196 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00054_sec00054_00790 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind00041_ind00041_01331 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20003_nat20003_02203 is only 0
# Number of tampered patches for image Tp_S_NNN_S_N_arc20084_arc20084_02188 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_art00018_art00018_10278 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art00044_art00044_10405 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20050_ind20050_02296 is only 1
# Number of tampered patches for image Tp_S_NRN_S_B_nat20006_nat20006_02206 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00044_arc00044_00264 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_nat00092_nat00092_00994 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind00061_ind00061_01350 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00017_nat00017_00941 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20072_arc20072_02463 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_sec10001_sec10001_20007 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00063_nat00063_00670 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00072_sec00072_10385 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20024_arc20024_02165 is only 1
# Number of tampered patches for image Tp_D_NND_S_N_sec00071_ind00084_11275 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_cha00046_cha00046_11006 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind00087_ind00087_01371 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_art20073_art20073_02320 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_pla20047_pla20047_01947 is only 1
# Number of tampered patches for image Tp_D_CNN_S_N_sec00042_ani00078_10495 is only 1
# Number of tampered patches for image Tp_S_NRN_S_O_arc00021_arc00021_01119 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B
is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20042_ind20042_01783 is only 1
# Number of tampered patches for image Tp_D_CRN_S_N_ani00008_ani00011_10221 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani20027_ani20027_02070 is only 0
# Number of tampered patches for image Tp_S_NRD_S_N_art20045_art20045_01851 is only 1
# Number of tampered patches for image Tp_S_NRD_S_N_art20008_art20008_01814 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc00010_arc00010_01109 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_art00065_art00065_01238 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20061_nat20061_02255 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_D_NRN_M_N_pla10123_cha10110_11556_gt.png'
# Number of tampered patches for image Tp_D_NRN_S_B_cha00065_txt00068_10177 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_ani10155_ani10155_12485 is only 0
# Number of tampered patches for image Tp_S_NRN_S_B_nat20099_nat20099_01603 is only 0
# Number of tampered patches for image Tp_D_NRN_S_N_nat10161_art00092_12085 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_cha20043_cha20043_02042 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ind00042_ind00042_00899 is only 1
# Number of tampered patches for image Tp_D_CRD_S_N_ind00074_cha00049_00474 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ind20001_ind20001_01742 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_sec20024_sec20024_01614 is only 1
# Number of tampered patches for image Tp_D_NNN_S_N_ind00032_cha00020_00447 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla20082_pla20082_02491 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_sec20059_sec20059_01649 is only 0
# Number of tampered patches for image Tp_D_CRD_S_B_cha00086_cha00065_00015 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla20005_pla20005_01905 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00046_arc00046_01080 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20084_arc20084_02417 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ani10220_ani10220_12390 is only 0
# Number of tampered patches for image Tp_D_NRN_S_N_art00099_ani00100_01382 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_txt00028_txt00028_20117 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_art00067_art00067_01239 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_cha20045_cha20045_02433 is only 1
# Number of tampered patches for image Tp_S_NRN_S_B_arc10107_arc10107_11166 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00028_sec00028_00767 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_sec20047_sec20047_01637 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_txt00007_txt00007_01265 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00035_nat00035_00951 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20026_ind20026_01767 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_nat00014_nat00014_20055 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc10124_arc10124_11883 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00085_nat00085_00680 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20073_arc20073_01713 is only 0
# Number of tampered patches for image Tp_S_NRN_S_N_art00017_art00017_01429 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_nat10140_nat10140_11952 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_ani10119_ani10118_11612 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_arc20080_arc20080_02192 is only 0
# Number of tampered patches for image Tp_D_NRN_S_B_sec00002_ani00017_01432 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_txt00005_txt00005_01264 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_cha00079_ani00068_00399 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani00006_ani00006_00833 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20064_ind20064_01805 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ani20054_ani20054_02097 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani00095_ani00095_00809 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_sec20013_sec20013_01448 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_pla00029_pla00030_10947 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00057_arc00057_01069 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat10132_nat10132_12141 is only 1
# Number of tampered patches for image Tp_D_NNN_S_N_ind00060_ind00058_01349 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_pla20022_pla20022_01922 is only 0
# Number of tampered patches for image Tp_S_NRN_S_B_arc00029_arc00029_01093 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_art00021_art00021_01208 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla00055_pla00055_01164 is only 1
# Number of tampered patches for image Tp_D_CNN_S_B_sec00023_sec00022_00044 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani00092_ani00092_00811 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_nat20015_nat20015_02215 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_N_sec20065_sec20065_01655_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_pla00084_pla00084_01186 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20040_nat20040_01544 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_sec00091_cha00023_00716 is only 1
# Number of tampered patches for image Tp_S_NRD_S_B_cha00100_cha00100_00875 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20038_arc20038_02174 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_art20052_art20052_01858 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20060_ind20060_02303 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20070_nat20070_01574 is only 0
# Number of tampered patches for image Tp_S_CRN_S_N_art10114_art10114_11596 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind00058_ind00058_00906 is only 1
# Number of tampered patches for image Tp_D_NRD_S_N_ind00030_ind00031_01323 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00021_sec00021_00766 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_sec20036_sec20036_01626 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20037_nat20037_02235 is only 1
# Number of tampered patches for image Tp_S_NRD_S_B_sec20033_sec20033_01623 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_art00038_art00038_01224 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_art00034_ani00058_01420 is only 1
# Number of tampered patches for image Tp_D_CRN_S_O_ani10103_ani10111_10636 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_sec
is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_ind20065_ind20058_01806 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ind20048_ind20048_01789 is only 0
# Number of tampered patches for image Tp_S_NNN_S_N_ind00081_ind00081_01365 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ind00036_ind00036_00450 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind00053_ind00053_00903 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_sec20030_sec20030_01620 is only 0
# Number of tampered patches for image Tp_S_NND_S_B_art00011_art00011_01201 is only 1
# Number of tampered patches for image Tp_S_NRN_S_B_nat20091_nat20091_01595 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc20038_arc20038_01491 is only 1
# Number of tampered patches for image Tp_D_CRN_M_O_pla10102_ani10104_10028 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NRN_S_B_ind10002_ind10002_20010_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_art20011_art20011_01817 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_cha10128_cha10128_12151 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art20011_art20011_02339 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art20021_art20021_01827 is only 1
# Number of tampered patches for image Tp_D_NRN_S_B_arc00051_ani00005_00271 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_sec00068_sec00068_00089 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_D_CRN_S_B_sec00093_sec00098_00113_gt.png'
# Number of tampered patches for image Tp_S_NRN_S_N_art00063_art00063_01028 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00023_sec00023_00748 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla00008_pla00008_00547 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind00009_ind00009_00884 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_art10105_ani10123_11599 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_ind00020_ind00010_00436 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_cha00065_cha00065_00856 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art00084_art00084_00534 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_B_arc20045_arc20045_01498_gt.png'
# Number of tampered patches for image Tp_S_NRN_S_N_cha10194_cha10194_12322 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_nat10157_nat10157_12044 is only 1
# Number of tampered patches for image Tp_D_CNN_M_N_sec10110_sec10101_10298 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_cha00011_ani00031_00331 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20062_ind20062_01803 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_nat00062_nat00062_00973 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_B_nat20010_nat20010_01514_gt.png'
# Number of tampered patches for image Tp_S_CNN_S_N_cha00017_cha00017_10311 is only 1
# Number of tampered patches for image Tp_D_CRN_S_N_nat10156_ani00099_12024 is only 1
# Number of tampered patches for image Tp_S_NRD_S_N_sec20097_sec20097_02141 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_cha00092_cha00092_00412 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_arc00097_arc00097_01033 is only 1
# Number of tampered patches for image Tp_D_CRD_M_N_arc00037_ani00005_10142 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20031_arc20031_02462 is only 1
# Number of tampered patches for image Tp_D_NRN_M_N_ani00021_ani00020_10212 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20020_ind20020_01761 is only 0
# Number of tampered patches for image Tp_S_NNN_S_N_sec20093_sec20093_01683 is only 1
# Number of tampered patches for image Tp_S_NRD_S_N_arc00043_arc00043_01082 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind00031_ind00031_01324 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec20036_sec20036_02450 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art00062_art00062_01027 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_ind20049_ind20049_01790 is only 0
# Number of tampered patches for image Tp_S_NNN_S_N_nat20054_nat20054_01558 is only 0
# Number of tampered patches for image Tp_S_NNN_S_B_cha20027_cha20027_02426 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_ind00073_art00012_00473 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec20071_sec20071_01661 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_cha10162_cha10162_12250 is only 1
# Number of tampered patches for image Tp_D_CNN_S_N_ani00087_ani00088_10102 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_N_sec00074_sec00074_00751_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_arc20037_arc20037_02173 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_sec00076_sec00076_00097 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00013_sec00013_00746 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_sec20022_sec20022_01612 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc00074_arc00074_00294 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani00086_ani00086_00206 is only 1
# Number of tampered patches for image Tp_S_NRD_S_B_art10106_art10106_11589 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20099_nat20099_02259 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_art00032_art00032_10467 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla20045_pla20045_02381 is only 0
# Number of tampered patches for image Tp_S_CRD_S_B_sec00002_sec00002_00022 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_ani00050_ani00055_10225 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_nat20039_nat20039_02237 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00035_arc00035_01089 is only 1
# Number of tampered patches for image Tp_D_NRN_S_B_arc00084_ani00058_00304 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_pla20050_pla20050_01950 is only 1
# Number of tampered patches for image Tp_S_NRN_S_B_cha10140_cha10140_12199 is only 0
# Number of tampered patches for image Tp_S_NRD_S_N_ind00006_ind00006_01304 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_sec00022_sec00022_00043 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_nat20004_nat20004_02204 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_nat20051_nat20051_01555 is only 0
# Number of tampered patches for image Tp_D_CRN_M_N_ani10104_ani00100_10093 is only 0
# Number of tampered patches for image Tp_D_NRN_S_N_cha10108_cha00062_11584 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind
is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ani00074_ani00074_00825 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00037_nat00037_00953 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_arc00051_arc00051_01075 is only 1
# Number of tampered patches for image Tp_S_CRD_S_B_art00027_art00027_10765 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20086_arc20086_02415 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_pla20068_pla20068_01968 is only 1
# Number of tampered patches for image Tp_D_CRD_S_N_ind00029_ind00088_00444 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla00095_pla00095_00616 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00061_arc00061_01065 is only 1
# Number of tampered patches for image Tp_D_NRN_M_N_ani00099_ani00100_10145 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_sec20052_sec20052_01642 is only 1
# Number of tampered patches for image Tp_D_NRN_M_N_nat10131_nat10132_11904 is only 0
# Number of tampered patches for image Tp_S_NND_S_N_arc20065_arc20065_02196 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_nat00021_nat00021_00943 is only 1
# Number of tampered patches for image Tp_D_CRD_S_N_ani00028_ani00058_00148 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20086_arc20086_01726 is only 0
# Number of tampered patches for image Tp_S_NNN_S_B_ind00064_ind00064_01352 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20005_nat20005_02205 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_txt00008_txt00008_01266 is only 1
# ...
# Number of tampered patches for image Tp_S_NNN_S_N_nat20026_nat20026_01530 is only 1
# Number of tampered patches for image Tp_D_NNN_S_N_ind00031_ind00030_00446 is only 1
# Number of tampered patches for image Tp_D_CRN_S_N_ani00050_ani00019_11856 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art20083_art20083_02313 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_sec00073_art00064_00725 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art20017_art20017_01823 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc20085_arc20085_01725 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NRN_M_N_cha10114_nat10114_12181_gt.png'
# Number of tampered patches for image Tp_D_NRN_S_N_art00023_art00092_11874 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc20057_arc20057_01697 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_cha00039_cha00039_00359 is only 1
# Number of tampered patches for image Tp_D_NNN_S_N_sec00086_cha00023_00705 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc20085_arc20085_02416 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_sec20094_sec20094_01684 is only 0
# Number of tampered patches for image Tp_D_NRN_M_N_arc00037_ani00005_10141 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_nat00034_nat00034_00950 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_pla20065_pla20065_02368 is only 1
# Number of tampered patches for image Tp_D_CND_S_N_ind00078_ind00077_00476 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00022_arc00022_01120 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20030_ind20030_02285 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_nat00019_nat00019_20032 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_N_art00059_art00059_01234_gt.png'
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_CNN_S_N_cha0003_cha00003_00323_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_art00063_art00063_01237 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_art00040_art00040_01414 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_cha10124_cha10124_12154 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00032_sec00032_00053 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_sec20020_sec20020_01610 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_N_sec00012_sec00012_00740_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_ani00023_ani00023_00010 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_sec20003_sec20003_02114 is only 0
# Number of tampered patches for image Tp_S_NNN_S_B_nat20056_nat20056_02251 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec20026_sec20026_02452 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00069_sec00069_00787 is only 1
# Number of tampered patches for image Tp_S_NNN_S_O_arc00045_arc00045_00265 is only 1
# Number of tampered patches for image Tp_D_CRN_S_N_ani10116_sec00098_11616 is only 1
# Number of tampered patches for image Tp_S_CNN_S_B_art20065_art20065_02499 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_pla00033_pla00033_01148 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_D_NRN_S_B_nat20009_nat20009_01513_gt.png'
# Number of tampered patches for image Tp_S_NRD_S_N_art20006_art20006_02498 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_arc00030_arc00030_00778 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_nat00034_nat00034_00954 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_arc00025_arc00025_01097 is only 1
# Number of tampered patches for image Tp_S_CNN_S_B_nat10109_nat10109_11354 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20038_nat20038_01542 is only 1
# Number of tampered patches for image Tp_D_NNN_S_B_sec00072_sec00072_00727 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_txt00004_txt00004_01263 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_sec20100_sec20100_01690 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_ind00006_ind00006_00883 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20098_arc20098_02187 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind00043_ind00043_00452 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla20063_pla20063_01963 is only 0
# Number of tampered patches for image Tp_S_CRN_S_N_pla00005_pla00005_01127 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani10157_ani10157_12465 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00048_arc00048_01078 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_cha20032_cha20032_02031 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_sec00098_ani00100_11629 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_ind00096_cha00083_01380 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20061_arc20061_01701 is only 1
# Number of tampered patches for image Tp_S_NRD_S_N_art10109_art10109_11573 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00016_arc00016_01114 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_arc20020_arc20020_02161 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_sec00099_sec00099_00119 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_art10005_art10005_20043 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc10101_arc10101_11167 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00047_nat00047_00966 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_cha00090_cha00090_10175 is only 1
# Number of tampered patches for image Tp_S_CRN_M_N_ani00099_ani00099_10094 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec20042_sec20042_01632 is only 0
# Number of tampered patches for image Tp_S_NNN_S_N_nat20089_nat20089_01593 is only 0
# Number of tampered patches for image Tp_S_NNN_S_B_arc20056_arc20056_01696 is only 0
# Number of tampered patches for image Tp_D_NRN_S_N_ani00033_ani00034_10236 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_sec00065_sec00065_00086 is only 1
# Number of tampered patches for image Tp_D_CRN_S_N_nat10145_ani00022_11986 is only 0
# Number of tampered patches for image Tp_S_CND_S_N_txt00084_txt00084_01290 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_ani10119_ani10119_11608 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20023_arc20023_02164 is only 1
# Number of tampered patches for image Tp_S_NRN_S_B_art00084_art00084_00929 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_art10114_art10114_11597 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind20026_ind20026_02461 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec00034_sec00034_00802 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_D_NRN_S_B_sec00079_pla00029_00100_gt.png'
# Number of tampered patches for image Tp_S_NRN_S_N_pla20042_pla20042_02383 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_arc00075_cha00063_00295 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_B_nat20009_nat20009_02209_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_art00050_art00050_01024 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_art00077_art00077_01394 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00085_nat00085_10588 is only 1
# Number of tampered patches for image Tp_D_NRN_S_B_cha00026_pla00009_00346 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ind00080_ind00080_00913 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_sec20034_sec20034_01624 is only 0
# Number of tampered patches for image Tp_S_NNN_S_B_pla00049_pla00049_01158 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla20076_pla20076_01976 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00064_arc00064_01062 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_ind00021_ind00021_01319 is only 1
# Number of tampered patches for image Tp_D_NRN_M_N_nat10108_cha00052_11364 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NRN_S_B_nat20014_nat20014_01518_gt.png'
# Number of tampered patches for image Tp_D_NNN_S_N_ind20047_ind20049_01788 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00014_nat00014_00940 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_sec20082_sec20082_01672 is only 1
# Number of tampered patches for image Tp_S_NNN_M_N_art00033_art00033_10552 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_pla00093_sec00097_11288 is only 1
# Number of tampered patches for image Tp_S_CND_S_B_sec00097_sec00097_00117 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc20082_arc20082_02190 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_ani10121_ani00100_11617 is only 1
# Number of tampered patches for image Tp_S_NRN_S_B_pla00082_pla00082_01184 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_art00020_art00020_00502 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc00018_arc00018_00238 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_cha20034_cha20034_02033 is only 0
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NRN_S_N_pla20025_pla20025_01925_gt.png'
# Number of tampered patches for image Tp_S_NRD_S_N_arc00059_arc00059_01067 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani00083_ani00083_00818 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_sec10115_sec10115_11531 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_pla00093_txt00070_11327 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani20044_ani20044_02087 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_ani20006_ani20006_02049 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art00054_art00054_01230 is only 1
# Number of tampered patches for image Tp_S_NRD_S_N_arc00042_arc00042_01083 is only 1
# Number of tampered patches for image Tp_D_NRD_S_N_sec00025_sec00098_00046 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_pla00073_pla00073_00601 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_N_ind20037_ind20037_01778_gt.png'
# Number of tampered patches for image Tp_S_CNN_S_N_sec20039_sec20039_02448 is only 0
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_D_CRD_S_B_sec20007_sec20007_01442_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_B_ani20003_ani20003_02402 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani10139_ani10139_12499 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc20078_arc20078_01718 is only 1
# Number of tampered patches for image Tp_S_NRD_S_B_sec20070_sec20070_01660 is only 1
# Number of tampered patches for image Tp_D_NNN_S_B_sec10001_arc00020_20006 is only 1
# Number of tampered patches for image Tp_D_NNN_S_B_art20029_art20034_02336 is only 0
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_D_NRD_S_N_sec00067_cha00030_00088_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_ind00042_ind00042_01332 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_sec00035_sec00035_00736 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_N_cha20004_cha20004_02003_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_arc20091_arc20091_02408 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_D_NRD_S_N_sec00011_sec00016_00031_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_ani20010_ani20010_02053 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20035_arc20035_01488 is only 1
# Number of tampered patches for image Tp_S_NRN_S_B_cha10111_cha10111_11690 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_art00002_art00002_00919 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20098_nat20098_02258 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_sec00090_ani00013_00717 is only 1
# Number of tampered patches for image Tp_S_NRD_S_N_ind00011_ind00011_01309 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_N_sec00094_sec00094_00755_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_sec00076_sec00076_00774 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_ind00032_ind00032_01325 is only 1
# Number of tampered patches for image Tp_S_NND_S_N_sec20099_sec20099_01689 is only 1
# Number of tampered patches for image Tp_S_CNN_S_N_arc00041_arc00041_01084 is only 1
# Number of tampered patches for image Tp_D_NNN_M_N_txt00040_txt00042_10007 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_pla00092_pla00092_00934 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NNN_S_N_nat00064_nat00064_00672_gt.png'
# Number of tampered patches for image Tp_D_NRN_S_N_art10105_pla00049_11595 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat20066_nat20066_01570 is only 0
# Number of tampered patches for image Tp_S_NNN_S_N_ani00089_ani00089_00209 is only 1
# Number of tampered patches for image Tp_S_NRN_S_B_txt00022_txt00022_20089 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_nat00081_nat00081_00677 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_arc20032_arc20032_01485 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_cha10102_cha10106_10159 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_ani10171_ani00001_12458 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_D_NRN_M_N_nat00089_pla10118_10583_gt.png'
# Number of tampered patches for image Tp_S_NNN_S_N_ind20004_ind20004_01745 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_arc00013_ani00005_00233 is only 1
# Number of tampered patches for image Tp_S_CRN_S_N_arc10127_arc10127_11891 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_arc00036_arc00036_01088 is only 1
# Number of tampered patches for image Tp_S_NNN_S_O_nat00053_nat00053_00969 is only 1
# Number of tampered patches for image Tp_S_NRN_S_N_nat10147_nat10147_11995 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art00074_art00074_01244 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_ani20008_ani20008_02051 is only 0
# Number of tampered patches for image Tp_S_NRN_S_N_ind00075_ind00075_00475 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_ani20003_ani20003_01452 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art00012_art00012_01202 is only 1
# Number of tampered patches for image Tp_D_NRN_S_N_cha00086_ani10119_11609 is only 1
# Number of tampered patches for image Tp_S_NNN_S_N_art20023_art20023_01829 is only 1
# Number of tampered patches for image Tp_S_NNN_S_B_art00060_art00060_01235 is only 1
# Number of tampered patches for image Tp_D_NNN_M_N_cha00031_ani10101_10048 is only 1
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_D_NRN_S_N_sec00093_cha00096_00713_gt.png'
# No such file: '/Users/Eshita/Desktop/Stuff/Github.nosync/Image Forgeries Detection/CASIA2/masks/Tp_S_NRD_S_N_pla20071_pla20071_01971_gt.png'
# Number of tampered patches for image Tp_S_NRN_S_N_txt00062_txt00062_01284 is only 1
